# %%
VS = [1.2, 1.3, 1.4, 1.5, 1.6, 1.7, 2.0, 2.5, 3.3, 3.5, 3.6, 3.7, 3.8, 4.0, 4.2, 4.4, 4.6, 4.8,4.8,5.0]
Out = [-40, -40, -30, -23.5, -22.2, -21.9, -21.5, -20, -20.2, -15.3, -11.8, -10.8, -9.7, -9.0, -8.7, -8.4, -8.15, -8,-22.9,-22.8]
In = [-25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -25, -40, -40]

# %%
import matplotlib.pyplot as plt
import numpy

# %%
plt.plot(VS, numpy.subtract(Out,In))
plt.xlabel("Supply Voltage (V)")
plt.ylabel("Gain (dB20)")
# Out:
# Text(0, 0.5, 'Gain (dB20)')
